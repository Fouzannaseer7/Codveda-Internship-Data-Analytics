# %% [markdown]
# Exploratory Data Analysis (EDA) on Iris Dataset

# %% [markdown]
# File: 1) iris.csv

# %% [markdown]
# 📘 Task: EDA on Iris Dataset

# %% [markdown]
# Import Required Libraries:

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [raw]
# pandas:
#  >Helps in loading and analyzing the dataset.
# matplotlib and seaborn:
#  >Used for data visualization (charts/plots).

# %% [markdown]
# Load the Dataset:

# %%
df = pd.read_csv("1) iris.csv")
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [raw]
# >pd.read_csv() loads the CSV file.
# >df.head() shows the first 5 rows of the dataset so we can get a quick preview.

# %% [markdown]
# Check Dataset Information

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# ...

# %% [raw]
# >df.info() shows columns, data types, and missing values.
# >df.describe() gives summary statistics like mean, median, min, max, etc.

# %% [markdown]
# Check for Missing and Duplicate Data:

# %%
print("Missing Values:\n", df.isnull().sum())
print("\nDuplicate Rows:", df.duplicated().sum())
# Out:
# Missing Values:
#  sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64
#
# Duplicate Rows: 3

# %% [raw]
# >isnull().sum() checks for any missing (empty) values.
# >duplicated().sum() counts repeated rows.

# %% [markdown]
# 👉 If duplicates are found:

# %%
df = df.drop_duplicates()

# %% [markdown]
# This removes any duplicate records.

# %% [markdown]
# Summary Statistics:

# %%
print(df.describe())
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %% [raw]
# >Re-run describe() to analyze cleaned data.
# >It shows values like:
#   Mean (average)
#   Standard deviation (spread)
#   Min, max, etc.

# %% [markdown]
# Data Visualization:

# %% [markdown]
# 1 Histogram:

# %%
df.hist(figsize=(10, 6), bins=15)
plt.suptitle("Histogram of Features")
plt.show()

# %% [raw]
# >A histogram shows the distribution of each feature (like sepal length).
# >Tells you whether the data is skewed or normally distributed.

# %% [markdown]
# 2 Boxplot:

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(data=df, orient="h")
plt.title("Boxplot of Features")
plt.show()

# %% [raw]
# >Boxplots show the spread of data and detect outliers.
# >It uses quartiles (25%, 50%, 75%) to show the distribution.

# %% [raw]
# 3 Pairplot:

# %%
sns.pairplot(df, hue="species")
plt.suptitle("Pairplot by Species", y=1.02)
plt.show()

# %% [raw]
# >Pairplots show scatter plots for every pair of features.
# >With hue="species", different flower types are colored differently.
# >Helps in identifying which features best separate the species.

# %% [raw]
# 4 Correlation Heatmap:

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(df.drop(columns=["species"]).corr(), annot=True, cmap="coolwarm")
plt.title("Feature Correlation Heatmap")
plt.show()

# %% [raw]
# >A heatmap shows how strongly features are related to each other.
# >Values range from:
#   //+1: Perfect positive relation
#   //-1: Perfect negative relation
#   //0: No relation

# %% [markdown]
#  Summary of EDA on Iris Dataset

# %% [markdown]
# Dataset Overview:

# %% [raw]
# >The dataset contains measurements of 150 flowers from 3 species:
#   Setosa, Versicolor, Virginica
# >Features include:
#  sepal_length
#  sepal_width
#  petal_length
#  petal_width
#  species (target/output variable)

# %% [markdown]
# Missing & Duplicate Data:

# %% [raw]
# >No missing values were found.
# >No duplicate rows after checking and cleaning.

# %% [markdown]
# Summary Statistics:

# %% [raw]
# >Mean values differ clearly across features.
# >Petal length and petal width have higher variability than sepal measurements.
# >Standard deviation shows petal-related features vary more between species.

# %% [markdown]
# Histograms

# %% [raw]
# >Showed how values are distributed.
# >Petal length and petal width had clearly distinct peaks per species, useful for classification.
# >Sepal width was more evenly spread.

# %% [markdown]
# Boxplots

# %% [raw]
# >Helped detect outliers (extremely high/low values).
# >Showed setosa species tends to have shorter petals with less variatio

# %% [markdown]
# Pairplot (Scatter Matrix)

# %% [raw]
# >Most useful plot for comparing species visually.
# >Showed:
#   //Setosa is clearly separated in almost all feature combinations.
#   //Versicolor and Virginica overlap a bit but still show patterns.

# %% [markdown]
# Correlation Heatmap

# %% [raw]
# >Strong positive correlation (near +1) between:
#   //petal_length and petal_width
#   //sepal_length and petal_length
# >Sepal_width had weaker or even negative correlation with others.
